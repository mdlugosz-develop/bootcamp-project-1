# %%
import pandas as pd

# %%
df=pd.read_csv("contract_awards_in_investment_project_financing_09-10-2024.csv")
df.head()
# Out:
#     As of Date  Fiscal Year      Region Borrower Country / Economy  \
# 0  09-Oct-2024         2020  SOUTH ASIA                Afghanistan
# 1  09-Oct-2024         2020  SOUTH ASIA                Afghanistan
# 2  09-Oct-2024         2020  SOUTH ASIA                Afghanistan
# 3  09-Oct-2024         2020  SOUTH ASIA                Afghanistan
# 4  09-Oct-2024         2020  SOUTH ASIA                Afghanistan
#
#   Borrower Country / Economy Code Project ID  \
# 0                              AF    P122235
# 1                              AF    P125597
# 2                              AF    P122235
# 3                              AF    P122235
# 4                              AF    P125597
#
#                                         Project Name  \
# 0  AF Irrigation Restoration and Development Project
# 1                Kabul Municipal Development Program
# 2  AF Irrigation Restoration and Development Project
# 3  AF Irrigation Restoration and Development Project
# ...

# %%
grouped_df=df.groupby(by=['Project ID', 'WB Contract Number',
                          'Supplier Contract Amount (USD)'])['Supplier Contract Amount (USD)'].sum().reset_index()
grouped_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_z/y17b_m151jb68st8bhhh9g_w0000gn/T/ipykernel_54813/3065484561.py in ?()
#       1 grouped_df=df.groupby(by=['Project ID', 'WB Contract Number',
# ----> 2                           'Supplier Contract Amount (USD)'])['Supplier Contract Amount (USD)'].sum().reset_index()
#       3 grouped_df.head()
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py in ?(self, level, drop, name, inplace, allow_duplicates)
#    1766                 else:
#    1767                     name = self.name
#    1768
#    1769             df = self.to_frame(name)
# -> 1770             return df.reset_index(
#    1771                 level=level, drop=drop, allow_duplicates=allow_duplicates
#    1772             )
#    1773         return None
#
# ...

# %%
df['Project Global Practice'].value_counts().head(10)
# Out:
# Project Global Practice
# Agriculture, Fishing and Forestry                                                26525
# Agriculture, Fishing and Forestry;Industry, Trade and Services                   21821
# Health                                                                           19666
# Education                                                                        16919
# Water, Sanitation and Waste Management                                           12402
# Social Protection                                                                11340
# Energy and Extractives                                                            8914
# Transportation                                                                    8541
# Public Administration                                                             8281
# Transportation;Agriculture, Fishing and Forestry;Industry, Trade and Services     5682
# Name: count, dtype: int64
